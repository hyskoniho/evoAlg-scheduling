# %%
import random
import sys
# Dicionário de aulas com seus respectivos caracteres
aula_dict = {
    'M': 'Matemática',
    'L': 'Língua Portuguesa',
    'E': 'Educação Financeira',
    'H': 'História',
    'G': 'Geografia',
    'C': 'Ciências',
    'R': 'Ensino Religioso',
    'U': 'Música',
    'I': 'Inglês',
    'F': 'Educação Física',
    'A': 'Arte'
}

# %%
# Tamanho do cromossomo 90 (3 séries, 6 aulas por dia, 5 dias por semana )
tamanho_cromossomo = 90
tamanho_populacao = tamanho_cromossomo

def gerar_horarios(tamanho_populacao, tamanho_cromossomo):
    horarios = [''.join(random.choice(list(aula_dict.keys())) for _ in range(tamanho_cromossomo)) for _ in range(tamanho_populacao)]
    return horarios

# Gerar uma lista com 100 strings de 90 caracteres
horarios = gerar_horarios(tamanho_populacao, tamanho_cromossomo)
horarios
# Out:
# ['AAEIMMGAUCLCIEHLGGCAHIRURCFHERFIRAHRCCUUCMAUHGEHAFECEFCLFRMREHFAHUCAACHEMGIEEMRHACHMMHCIFF',
#  'MARRHHIMRCEEAIRLIMLCRFHHEEGARGFUUIEELUCMAAMUCMIMGAUGFFCEEURGHHAREIGICHHUAIRHFEIHUFCRLGFEMF',
#  'RHIHIHFGFRFRGFHGCAUEEUGURACLEMARHRUMFAFUFAACAURIGLLGRAIUAFCEUHHEREIALFICILIRCLMUUUHHFEIUGH',
#  'EFUGCACAAIMHGFHARAGCCGLIIRLAGFCMHAHUCGIMAMMRRGMCMLFMLLHCUEIHALMLIUCAFHREAFCGGICIFARHRHHERR',
#  'ELMFAUFAAAUULGFHRRAFILIEFLAGCAUFAAHAIFUFCUHAAIHEFRIFRICHHCLIMGFRCRELHREGGCLGHAEILMEMRIMMCG',
#  'HMHGLCHUUMRMHICHHULHMMFEMGIGURGRFCGCUFAGLCRMHFAUERHMUFFGLCLIMAGFHLRFUGFLHRIAECAGFFCREAMALU',
#  'IAHGGLCLUMRARFAHUEFHHCARRCACMHHICEEMMMGFHCHRFCUACMIFCIMCAAUFRUFRGHGMMFFAUGHAEHAMELHFCHLALA',
#  'ULILGGAEIFFMMUFCFUCAMLRMCLAFCCFGGCAUFCREHIGMHLCUMUFCMHLMFCAIIRMFECEFLMHFMLIIRAAAUAEICHHUFH',
#  'GCHMRLMIGMCUIEALACFRUGGAFUUEHFAGCCIHGERIRFILCHUFCERLLCGUCEAHMIFLCCAMCLCRHGIFRAIEGEMCEGGRHE',
#  'AHRFRMAFIHFRMMCLUMLGGRGAICAIULEEEAAEUCGRUEHFLRUEULEMFFMECRHMHIIGEFIAEUMFRCHLHCCAGECHFFHUUG',
#  'IAGUAFFGGHFCGLLURMHEMURCGUEUHHMRLLUAFURLIIHUCECHCURFFIFICRGIFEMICRICCIHMGILEARAEAHUACRAEAU',
#  'EHHALAEGAIECFRIECIAMFLUILEMGMRRRIEAEACLMFCIGMIMHHLMHLLMFUCEREHEUACGERICUCAIUIHFMRIRCCCFGLM',
#  'ICLAHHLMLAGRLUCMGIEHGRCICIUHMCMECEREMLALMFAFMLGELFLCIAFMAMLUMGIHIULGEFLEFCEGHGLEECMHFFMMAC',
#  'IEEUCCLAIEGCFULUEFGMILUAMEMRIEGUHEGRFMHEGUUURHEFRHGHFEIGIFEMCFRHLERLEGFMIIAUIMIEUUUFCFERUU',
#  'RCGRHRRCUHUFUUGAMEFUIGRHCGAUHUGHUMMMIIMCHLIIACFMUGAIHUUHUUFUUMGGAAHEMUUUHEFHCREEAEECAUERUH',
#  'FURAGHEGLMFICFUAFHIEUMRCECLLFLIFRECEGUACLGLAFUIFAHHARIMHEFFCMEMMEAHGAMHRFCCAIEUFLMCMUMIFFM',
#  'AIGIEGAGCAICLCMIAECULGEHGGMFURAGEGMUEFCUFAUCLMURHRGLLCACLIFLFLCAAGHGRCHCGMHLIURLLAGHCCHEEM',
#  'LEMFHHLEAGMEGHCRMFGGCEHAFEHFMURLIEAUURHUMEACCFHIRELMRUGGIGLCGIUIUFFHEHCARIAGCLURHHRMLLHIIR',
#  'IUGGFALCUHHMUMFGUIIMIGRMMEHLAGAFUHFHHFRRMGIGUUUCECFGIIIERMIICRAHCCGRCHGLUELUGRIHILHHEHLLGA',
#  'IFRAHFGUCUAICMLGMGUIAUREMLCGCMUMCLLCIRERAMMRERMCGAIMAEUCLHUCLIRIEAUUUUUAMLEFECAFUGMHACIMRC',
#  'UAHRUUMIIARUECEHUERRRREAEEIIGMHGCAIAHHMCIRLULRGLACCUEHHHUHIHEEGRIEULUGFIRRULHAMCFCAMRRGMEA']

# %%
# Definir restrições para as aulas
restricoes = {
    0: {  # Segunda-feira
        'G': ['manhã'],  # Geografia até 10h50
        'H': ['manhã'],  # História até 10h50
        'M': ['manhã'],  # Matemática até 10h50
    },
    1: {  # Terça-feira
        'G': ['manhã'],  # Geografia até 10h50
        'H': ['manhã'],  # História até 10h50
        'M': ['manhã'],  # Matemática até 10h50
    },
    2: {  # Quarta-feira
        'G': ['manhã'],  # Geografia até 10h50
        'H': ['manhã'],  # História até 10h50
        'M': ['manhã'],  # Matemática até 10h50
        'F': ['manhã']  # Educação Física somente pela manhã
    },
    3: {  # Quinta-feira
        'G': ['manhã'],  # Geografia até 10h50
        'H': ['manhã'],  # História até 10h50
        'M': ['manhã'],  # Matemática até 10h50
    },
    4: {  # Sexta-feira
        'G': ['manhã'],  # Geografia até 10h50
        'H': ['manhã'],  # História até 10h50
        'M': ['manhã'],  # Matemática até 10h50
        'C': ['somente']  # Ciências somente na sexta-feira
    }
}


def validar_horario(horario, restricoes):
    ponto = 0
    for dia, regras in restricoes.items():
        aulas_do_dia = horario[dia * 6:(dia + 1) * 6]  # Cada dia tem 6 aulas, dia vai de 0 (segunda) a 4 (sexta)
        for aula, condicoes in regras.items():
            # Verificar se há restrições de horário
            if 'manhã' in condicoes and aula in aulas_do_dia[3:]:
                ponto +=1
            if 'somente' in condicoes and aula not in aulas_do_dia:
                ponto +=1  # Aula deve estar presente no dia específico
    return ponto

# Validar cada horário individualmente
for horario in horarios:
    print(f"Validando o horário: {horario}")
    pontos = validar_horario(horario, restricoes)
    print(f"Pontuação para este horário: {pontos}\n")
# Out:
# Validando o horário: AAEIMMGAUCLCIEHLGGCAHIRURCFHERFIRAHRCCUUCMAUHGEHAFECEFCLFRMREHFAHUCAACHEMGIEEMRHACHMMHCIFF
# Pontuação para este horário: 3
#
# Validando o horário: MARRHHIMRCEEAIRLIMLCRFHHEEGARGFUUIEELUCMAAMUCMIMGAUGFFCEEURGHHAREIGICHHUAIRHFEIHUFCRLGFEMF
# Pontuação para este horário: 5
#
# Validando o horário: RHIHIHFGFRFRGFHGCAUEEUGURACLEMARHRUMFAFUFAACAURIGLLGRAIUAFCEUHHEREIALFICILIRCLMUUUHHFEIUGH
# Pontuação para este horário: 4
#
# Validando o horário: EFUGCACAAIMHGFHARAGCCGLIIRLAGFCMHAHUCGIMAMMRRGMCMLFMLLHCUEIHALMLIUCAFHREAFCGGICIFARHRHHERR
# Pontuação para este horário: 6
#
# Validando o horário: ELMFAUFAAAUULGFHRRAFILIEFLAGCAUFAAHAIFUFCUHAAIHEFRIFRICHHCLIMGFRCRELHREGGCLGHAEILMEMRIMMCG
# Pontuação para este horário: 2
#
# Validando o horário: HMHGLCHUUMRMHICHHULHMMFEMGIGURGRFCGCUFAGLCRMHFAUERHMUFFGLCLIMAGFHLRFUGFLHRIAECAGFFCREAMALU
# Pontuação para este horário: 6
#
# Validando o horário: IAHGGLCLUMRARFAHUEFHHCARRCACMHHICEEMMMGFHCHRFCUACMIFCIMCAAUFRUFRGHGMMFFAUGHAEHAMELHFCHLALA
# Pontuação para este horário: 5
#
# Validando o horário: ULILGGAEIFFMMUFCFUCAMLRMCLAFCCFGGCAUFCREHIGMHLCUMUFCMHLMFCAIIRMFECEFLMHFMLIIRAAAUAEICHHUFH
# Pontuação para este horário: 4
#
# Validando o horário: GCHMRLMIGMCUIEALACFRUGGAFUUEHFAGCCIHGERIRFILCHUFCERLLCGUCEAHMIFLCCAMCLCRHGIFRAIEGEMCEGGRHE
# Pontuação para este horário: 5
#
# Validando o horário: AHRFRMAFIHFRMMCLUMLGGRGAICAIULEEEAAEUCGRUEHFLRUEULEMFFMECRHMHIIGEFIAEUMFRCHLHCCAGECHFFHUUG
# Pontuação para este horário: 4
#
# Validando o horário: IAGUAFFGGHFCGLLURMHEMURCGUEUHHMRLLUAFURLIIHUCECHCURFFIFICRGIFEMICRICCIHMGILEARAEAHUACRAEAU
# Pontuação para este horário: 4
#
# Validando o horário: EHHALAEGAIECFRIECIAMFLUILEMGMRRRIEAEACLMFCIGMIMHHLMHLLMFUCEREHEUACGERICUCAIUIHFMRIRCCCFGLM
# Pontuação para este horário: 3
#
# Validando o horário: EUAAUMLRUMUGALRFGGUEFCHCGRHHAMGAALCGUEHLEGLHUCHLMRLUELULMGLCRMGRFLFGAAHCRGGCFRECGFFILLGLCR
# Pontuação para este horário: 9
#
# Validando o horário: IMAGHGCLIMAAMCFHIHIMMIGRUHLLEEMMEAMCRLMFECAHELMAFHAALFGRUMIIICFUREREFRFAEGFFIUURUMUHHHGLUH
# Pontuação para este horário: 6
#
# Validando o horário: UACFCFEUMFEARLUCAGFFLMRHFGGGFFIRFHIHMUAHUCGLGFULCFAMRFEAHLUMIRMLCMFICRCHFARIACCUREGEIICHCM
# Pontuação para este horário: 5
#
# Validando o horário: ACGRFHMIGELUCGUGIFICLGUEIFAEHAGHUELCFHLGGICIURUCLHLMECMMUAHGAAHLIERRCFFACCAFUMAFACEMHLRHUU
# Pontuação para este horário: 6
#
# Validando o horário: UREACMGGUGLUMRIFFUCGEREIFMEUUFFIHMHCUUIHMMLRAGHUHUFRHLAHAURRELHAGREELUICILGFHGLLGRERRERAMA
# Pontuação para este horário: 4
#
# Validando o horário: CALHGRMGEELCHLFCMEEAHFHIRMFHGGGAAMAAMLGICMUHIRHGICUEMMHMFRLRELHFCRRCFRFLLACRRGRREEAFFACUML
# Pontuação para este horário: 7
#
# Validando o horário: FLLLIGIHRMUIRIGEUMHELRUFLRRIFUMEAFEGULCMRRMFMRCFAUCHGAREECHEERUGHFMELEGLEIAFMMLCHGEHFCRRIG
# Pontuação para este horário: 4
#
# Validando o horário: CCHAILHLEMGEFAIUIUCHCFGIALMEHFHCFERUUCGILLACMIIRUEGAFMUFFFUUUFHHLUHIRHAIRIMCELCCIGAFFGFHLC
# Pontuação para este horário: 5
#
# Validando o horário: ALUIMRUIAIGFHCRFUEMGEMHILFCEELUAAIIIHEEMUCRMCGIRMACHUGHRMCHUIMIILIFAEHMUUICMLEHUMUMRMRLREC
# Pontuação para este horário: 5
#
# Validando o horário: RGHAFHUHGHIRAARUEUACARIFCMFHAUCHIFGFEFMHLGLIIAUHREAUUAGUAAAGLMEAILGHUGLRFLEUFMIUFMRCRGICIG
# Pontuação para este horário: 3
#
# Validando o horário: HAURLUULICILEEGAEFUMRFALGGMIMMCRCUFACCUMAIEIEIGARGLUMGCCLAHIAIGGHRCHMUELRERCMAMGUHHGMFHFRH
# Pontuação para este horário: 3
#
# Validando o horário: RURUMAIAEALRLAEGLFAECUHFLFGUAHRRIHIUCLMLRMRGRAARAGAMHCLEMGLRAAEFECMIRUCLERIGGAMHCFGRFFMREF
# Pontuação para este horário: 6
#
# Validando o horário: FUUAAHMGCEFGUIICAHALAHRLLCMMGLGIHFLFHUAEMGAAMUUAAHCRMULCRIIGEUACRIUAFFFCLLHFAMLIMMUEUGGAMA
# Pontuação para este horário: 6
#
# Validando o horário: AMCLERLFGCMFHFAIELEIAFMCIAEMAAREGLHMHHRRHUCRHMUUCRIHIAEUHEHCAIARAIGRFLUIHUHRAUMGRUHLMLIHER
# Pontuação para este horário: 4
#
# Validando o horário: EFRAAFFUGLMIIIMAUREGUEUUECMMMUMAMHRGERIELMGALMGUFMGMHMIIEIFMGEHIFCMFCECLUFEIHFFHUELMEIHCGF
# Pontuação para este horário: 2
#
# Validando o horário: GUCAFLMAICCRGGIURURUGHHIIHRHAFAMFEFHECAIAEEACAHCLIERMUFRLGFUFHFIGUUCAUEFFUURRFUARRRCIURIMM
# Pontuação para este horário: 3
#
# Validando o horário: GRAFGMGCHUAECHEGCFIIFLUUGLMHRERUHMRRUUMHGMMFFFFLCMLUMMGIGEARIAEFAGEGEGEAMGRAGLCUGUAIGHEAUH
# Pontuação para este horário: 6
#
# Validando o horário: IRCALEAACFURHRHMACHCGFIMUGLURURAUGLICMGRMRIMLEFHRLLGACIFGERFMLCLUACCUIHRAUMRMGILRMHCHGHGFR
# Pontuação para este horário: 3
#
# Validando o horário: MGLEACGFFECFCMAUMGELAFCEREFHLHCIMEFCCIGEFRIMLLHELUGAUEEUMFMGRGIEFACMMGILIRMLCAGGGMACECUEEL
# Pontuação para este horário: 4
#
# Validando o horário: LIEUGLAGLIHCUUGGRLICMGIHCAMFGHLRFLUUMFLLREIIECERUEULHMELMHCMGGUFRCAHHRUEHFGLIFAMCMRIFAMRFL
# Pontuação para este horário: 7
#
# Validando o horário: LAEGUFUHFMFEHFCRIMAIFECCMRFAEHUHUFAIRIUECUCFEMERFCEHGFRRGMUCFAFHHAMLHLGFAFIRAMGUCFGLIFGHLL
# Pontuação para este horário: 5
#
# Validando o horário: ACEAIELHHIGALLGRAUAFFIUUECMUGMUUMFUMHFMIHLUMGLAAEMAFUIHGIHAARGCIHRMRLRFUFAUFGACUFLEEUECGGC
# Pontuação para este horário: 3
#
# Validando o horário: IMGIRCHEMHARAULLRMAIMMLUEIAIEGAFULMIIIUUMAFIFAIUHHLELFGMFIFUMIEUIUEECHAHIMRFCUFRAFIFHIURMG
# Pontuação para este horário: 5
#
# Validando o horário: HMHMHLLMFHAGIIGLUHLIFHGLECCCLCRMUGFIAEHCEGHLEUECCCGHGFEIEIMLHLLEIIIHIRGHFFUMHAFGHULUGEUCHR
# Pontuação para este horário: 7
#
# Validando o horário: UIMUMLHUGIAGCAUCMAECMCFUHMIGARHLIIUHRHGMMMGEUCUUICMMMFAFMRMMIMFGGMGCRCECLEGEGFGUMCCFFRCCRU
# Pontuação para este horário: 5
#
# Validando o horário: MEULFGIAEGUUHGGCUGMUIMLUFGFIHERUEMERMILCIAUEGCGUIGHECIIRIILEUGLAAHHFHUALMUMFHLACEEEHIEUCCF
# Pontuação para este horário: 6
#
# Validando o horário: GGRGHLLCEGRIILURMUHHHIRCUILEILLHCHRIIFAGUMFCEURHIELUALICGHUGLUFHARRAMIGHGGEILIEGUGFGAMRLIA
# Pontuação para este horário: 5
#
# Validando o horário: AGAFRGIEICLEAMMCFLHRRCFLEHLRGCRFUHUARLLLRIRLGLALHEAEHAGRMMGLLLRIRURALRRGALILUGGMRFUFAECEEU
# Pontuação para este horário: 3
#
# Validando o horário: CEFLGEUACFHIGHIRLFAFCIRCFAAEAMUCLUAACFRAMCEUUGEFFHRHAAFIIAGLIRUCHHCIHCFCUECGUULIAAICMARLEE
# Pontuação para este horário: 5
#
# Validando o horário: RCGRHRRCUHUFUUGAMEFUIGRHCGAUHUGHUMMMIIMCHLIIACFMUGAIHUUHUUFUUMGGAAHEMUUUHEFHCREEAEECAUERUH
# Pontuação para este horário: 6
#
# Validando o horário: FURAGHEGLMFICFUAFHIEUMRCECLLFLIFRECEGUACLGLAFUIFAHHARIMHEFFCMEMMEAHGAMHRFCCAIEUFLMCMUMIFFM
# Pontuação para este horário: 6
#
# Validando o horário: AIGIEGAGCAICLCMIAECULGEHGGMFURAGEGMUEFCUFAUCLMURHRGLLCACLIFLFLCAAGHGRCHCGMHLIURLLAGHCCHEEM
# Pontuação para este horário: 4
#
# Validando o horário: LEMFHHLEAGMEGHCRMFGGCEHAFEHFMURLIEAUURHUMEACCFHIRELMRUGGIGLCGIUIUFFHEHCARIAGCLURHHRMLLHIIR
# Pontuação para este horário: 8
#
# Validando o horário: IUGGFALCUHHMUMFGUIIMIGRMMEHLAGAFUHFHHFRRMGIGUUUCECFGIIIERMIICRAHCCGRCHGLUELUGRIHILHHEHLLGA
# Pontuação para este horário: 8
#
# Validando o horário: IFRAHFGUCUAICMLGMGUIAUREMLCGCMUMCLLCIRERAMMRERMCGAIMAEUCLHUCLIRIEAUUUUUAMLEFECAFUGMHACIMRC
# Pontuação para este horário: 5
#
# Validando o horário: UAHRUUMIIARUECEHUERRRREAEEIIGMHGCAIAHHMCIRLULRGLACCUEHHHUHIHEEGRIEULUGFIRRULHAMCFCAMRRGMEA
# Pontuação para este horário: 4

# %%
def verificar_sobreposicao(horario):
    pontuacao = 0
    # Iterar sobre os horários de cada série (sub-horários de 30 caracteres)
    sub_horarios = [horario[i:i+30] for i in range(0, len(horario), 30)]
    # Iterar sobre cada período (6 aulas por dia, 5 dias por semana)
    for dia in range(5):
        for aula_index in range(6):
            aulas_no_horario = [sub_horario[dia * 6 + aula_index] for sub_horario in sub_horarios]
            # Contar quantas vezes cada aula aparece simultaneamente no mesmo período
            contador_aulas = {}
            for aula in aulas_no_horario:
                if aula in contador_aulas:
                    contador_aulas[aula] += 1
                else:
                    contador_aulas[aula] = 1
            # Penalizar se uma aula ocorrer em mais de uma sala ao mesmo tempo
            for aula, count in contador_aulas.items():
                if count > 1:
                    pontuacao += (count - 1)  # Penaliza pela sobreposição da mesma aula em mais de uma sala
    
    return pontuacao

for horario in horarios:
    print(f"Verificando sobreposição para o horário: {horario}")
    pontos = verificar_sobreposicao(horario)
    print(f"Pontuação para este horário: {pontos}\n")
# Out:
# Verificando sobreposição para o horário: AAEIMMGAUCLCIEHLGGCAHIRURCFHERFIRAHRCCUUCMAUHGEHAFECEFCLFRMREHFAHUCAACHEMGIEEMRHACHMMHCIFF
# Pontuação para este horário: 11
#
# Verificando sobreposição para o horário: MARRHHIMRCEEAIRLIMLCRFHHEEGARGFUUIEELUCMAAMUCMIMGAUGFFCEEURGHHAREIGICHHUAIRHFEIHUFCRLGFEMF
# Pontuação para este horário: 13
#
# Verificando sobreposição para o horário: RHIHIHFGFRFRGFHGCAUEEUGURACLEMARHRUMFAFUFAACAURIGLLGRAIUAFCEUHHEREIALFICILIRCLMUUUHHFEIUGH
# Pontuação para este horário: 8
#
# Verificando sobreposição para o horário
# Pontuação para este horário: 8
#
# Verificando sobreposição para o horário: IEEUCCLAIEGCFULUEFGMILUAMEMRIEGUHEGRFMHEGUUURHEFRHGHFEIGIFEMCFRHLERLEGFMIIAUIMIEUUUFCFERUU
# Pontuação para este horário: 8
#
# Verificando sobreposição para o horário: RCGRHRRCUHUFUUGAMEFUIGRHCGAUHUGHUMMMIIMCHLIIACFMUGAIHUUHUUFUUMGGAAHEMUUUHEFHCREEAEECAUERUH
# Pontuação para este horário: 6
#
# Verificando sobreposição para o horário: FURAGHEGLMFICFUAFHIEUMRCECLLFLIFRECEGUACLGLAFUIFAHHARIMHEFFCMEMMEAHGAMHRFCCAIEUFLMCMUMIFFM
# Pontuação para este horário: 11
#
# Verificando sobreposição para o horário: AIGIEGAGCAICLCMIAECULGEHGGMFURAGEGMUEFCUFAUCLMURHRGLLCACLIFLFLCAAGHGRCHCGMHLIURLLAGHCCHEEM
# Pontuação para este horário: 9
#
# Verificando sobreposição para o horário: LEMFHHLEAGMEGHCRMFGGCEHAFEHFMURLIEAUURHUMEACCFHIRELMRUGGIGLCGIUIUFFHEHCARIAGCLURHHRMLLHIIR
# Pontuação para este horário: 5
#
# Verificando sobreposição para o horário: IUGGFALCUHHMUMFGUIIMIGRMMEHLAGAFUHFHHFRRMGIGUUUCECFGIIIERMIICRAHCCGRCHGLUELUGRIHILHHEHLLGA
# Pontuação para este horário: 11
#
# Verificando sobreposição para o horário: IFRAHFGUCUAICMLGMGUIAUREMLCGCMUMCLLCIRERAMMRERMCGAIMAEUCLHUCLIRIEAUUUUUAMLEFECAFUGMHACIMRC
# Pontuação para este horário: 11
#
# Verificando sobreposição para o horário: UAHRUUMIIARUECEHUERRRREAEEIIGMHGCAIAHHMCIRLULRGLACCUEHHHUHIHEEGRIEULUGFIRRULHAMCFCAMRRGMEA
# Pontuação para este horário: 4

# %%
def fitting(horario):
    # Quantidade desejada de cada aula
    requisitos = {
        'M': 18,
        'L': 21,
        'E': 3,
        'H': 6,
        'G': 6,
        'C': 6,
        'R': 3,
        'U': 3,
        'I': 15,
        'F': 3,
        'A': 6    
    }
    # Contar a quantidade de cada letra no horário
    contador = {letra: horario.count(letra) for letra in aula_dict.keys()}
    
    # Calcular a pontuação com base na diferença entre o esperado e o real
    pontuacao = 0

    # Pontos para quantidade total de aulas 
    for aula, qtd_desejada in requisitos.items():
        pontuacao += max(0, abs(qtd_desejada - contador.get(aula, 0)))
    
    # Pontos para quantidade semanal de aulas
    for i in range(0, len(horario), 30):
        sub_horario = horario[i:i+30]
        # Contar a quantidade de cada letra no sub-horário
        contador = {letra: sub_horario.count(letra) for letra in aula_dict.keys()}
        
        # Calcular a pontuação com base na diferença entre o esperado e o real
        for aula, qtd_desejada in requisitos.items():
            qtd_desejada_por_sub = qtd_desejada // 3
            pontuacao += max(0, abs(qtd_desejada_por_sub - contador.get(aula, 0)))
    
        pontuacao += validar_horario(sub_horario, restricoes)     
    pontuacao += verificar_sobreposicao(horario)     
    
    return pontuacao

# %%
# Gerar uma lista com 100 strings de 90 caracteres
horarios = gerar_horarios(tamanho_populacao=2, tamanho_cromossomo=90)
lista_fitting = []
# Exibir os 100 horários gerados com suas pontuações
for horario in horarios:
    lista_fitting.append((fitting(horario),horario))

# Ordenar a lista com base na pontuação (melhores pontuações primeiro)
lista_fitting.sort(key=lambda x: x[0])

lista_fitting
# Out:
# [(136,
#   'EARLCCLRCRLAHCRFEGGCHHCRFMAELARIGEIGMAIARAGMLFMARAICIIIMMLFULEAHAAEHGEMCAIUACMIHRUAIIGEUMM'),
#  (146,
#   'FEARRLMICCILHUGLIGLRHGUFMLLCHUEMHICRAFCUHAUACHULMLMMAGRIUAECAHIIEEAMEEFCHUAGRCGHRUCFRIHCGR')]

# %%
def crossover(horario1, horario2, num_pontos=3, prob_crossover=0.8):
    
    if random.random() < prob_crossover:
        # Escolher múltiplos pontos de corte aleatórios
        pontos_corte = sorted(random.sample(range(1, len(horario1)), num_pontos))
        
        # Fazer o crossover de múltiplos pontos
        filho1, filho2 = '', ''
        ultimo_ponto = 0
        for i, ponto in enumerate(pontos_corte):
            if i % 2 == 0:
                filho1 += horario1[ultimo_ponto:ponto]
                filho2 += horario2[ultimo_ponto:ponto]
            else:
                filho1 += horario2[ultimo_ponto:ponto]
                filho2 += horario1[ultimo_ponto:ponto]
            ultimo_ponto = ponto
        
        # Adicionar a última parte
        if len(pontos_corte) % 2 == 0:
            filho1 += horario1[ultimo_ponto:]
            filho2 += horario2[ultimo_ponto:]
        else:
            filho1 += horario2[ultimo_ponto:]
            filho2 += horario1[ultimo_ponto:]
    else:
        # Se não houver crossover, os filhos são iguais aos pais
        filho1, filho2 = horario1, horario2
        
    return filho1, filho2

# %%
def mutacao(horario, taxa_mutacao=0.03):
    # Converter o horário em uma lista de caracteres para facilitar a mutação
    horario_list = list(horario)   

    # 1. Mutação Tradicional
    for i in range(len(horario_list)):
        if random.random() < taxa_mutacao:
            # Escolher uma nova aula aleatória diferente da atual
            novas_opcoes = [aula for aula in aula_dict.keys() if aula != horario_list[i]]
            horario_list[i] = random.choice(novas_opcoes)
    
    # Converter a lista de volta para string
    return ''.join(horario_list)

# %%
for i in range(100000):  # Loop com 100000 iterações (pode ajustar conforme desejar)
    # Calcular a pontuação de cada horário e armazenar em uma lista
    lista_fitting = []
    for horario in horarios:
        lista_fitting.append((fitting(horario), horario))

    # Ordenar a lista com base na pontuação (melhores pontuações primeiro)
    lista_fitting.sort(key=lambda x: x[0])
    if i == 0:
        pontuacao_menor = lista_fitting[0][0]
    pontuacao_menor_atual = lista_fitting[0][0]
    
    if lista_fitting[0][0] == 0:
        print(f'''Geracao {i}, {lista_fitting[0]}\n
                        {lista_fitting[1]}\n
                        {lista_fitting[2]}''')
        break
    elif pontuacao_menor_atual <pontuacao_menor:
        pontuacao_menor = pontuacao_menor_atual
        sys.stdout.write(f'''Geracao {i}, {lista_fitting[0]}\n{lista_fitting[1]}\n{lista_fitting[2]}\n''')
    # Pegar os 50 primeiros horários com as melhores pontuações
    # melhores_horarios = lista_fitting
    melhores_horarios = lista_fitting[:50]
    filhos = []
    
    for i in range(0, len(melhores_horarios), 2):
        if i + 1 < len(melhores_horarios):
            pai1 = melhores_horarios[i][1]
            pai2 = melhores_horarios[i + 1][1]
            filho1, filho2 = crossover(pai1, pai2)
            filhos.extend([filho1, filho2])
    filhos_mutados = [mutacao(filho) for filho in filhos]

    # Gerar outros 50 horários novos
    # novos_horarios = gerar_horarios(50)
    # horarios = novos_horarios + filhos_mutados
    # melhores_horarios = lista_fitting[:25]
    horarios = [horario for _, horario in melhores_horarios] + filhos_mutados
    # horarios =  filhos_mutados + novos_horarios
    # horarios =  filhos_mutados
# Out:
# Geracao 1, (121, 'FEARRMMICCILHUGLIGLRHGCRFMAELARIGEIGMAIARAGMLFMARAICIIIIUAECLEAHHAEHGEMCAIUACMIHRUAIIGEUMM')
# (136, 'EARLCCLRCRLAHCRFEGGCHHCRFMAELARIGEIGMAIARAGMLFMARAICIIIMMLFULEAHAAEHGEMCAIUACMIHRUAIIGEUMM')
# (146, 'FEARRLMICCILHUGLIGLRHGUFMLLCHUEMHICRAFCUHAUACHULMLMMAGRIUAECAHIIEEAMEEFCHUAGRCGHRUCFRIHCGR')
# Geracao 5, (111, 'FEGURMMICCILHUGLIGLRHGCRFMAELARIGAIGMAIACAGMLFMARAICIRIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUMM')
# (114, 'FEARCCMICCILHUGLIGLRHGUFMLLMHUEMHICRAMCURAUACHULMHICIIIMMLFUAHIIEEAMGEFCAIUACMIHRUUIIGEUMM')
# (117, 'FEAGRMMICCILHUGLIGLLHECRFMAELARIGEIGMAIARAMMLFMARAIMAIIIUAFULEAHLAEHGEMCAIFACMIHRGAIIGEUML')
# Geracao 6, (106, 'FEGURMMICCILHUGLIGLRHGUFMLLMHUEMHICRAMCURAGMLFMARAICIRIMMLFULEMHLAEHGEFCAIUACMIHRUUIIGEUMM')
# (111, 'FEGURMMICCILHUGLIGLRHGCRFMAELARIGAIGMAIACAGMLFMARAICIRIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUMM')
# (112, 'FEAGRMMICCILHUGLIGLLHGCRFMAELARIGEIGMAIARAGMLFMARAICIIIMMLFULEAHLAEHGEMCAIUACMIHRGAIIGEUML')
# Geracao 7, (100, 'FEGURMMICCILHUGLIGLRHGUFMLLMHUEMHICRMAIACAGMLFMARAICIRIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUMM')
# (106, 'FEGURMMICCILHUGLIGLRHGUFMLLMHUEMHICRAMCURAGMLFMARAICIRIMMLFULEMHLAEHGEFCAIUACMIHRUUIIGEUMM')
# (107, 'EARLCCMIFCULHUGFIGLCHHCRFMMELARIGEIGMLIARAGMLFMARAICIIIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUML')
# Geracao 8, (98, 'FEGURMMICCILHUGLIGLRHAUFMLLMHUEMHICRMAIACAGMLFMARAICIRIMMLFUMEMHLAEHGEMCAIUACMIHRUUIIGEUMM')
# (100, 'FEGURMMICCILHUGLIGLRHGUFMLLMHUEMHICRMAIACAGMLFMARAICIRIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUMM')
# (100, 'FEARCCMICCILHUGLIGLRHGCRFMAMLALIGEIGMAIARAGMLCMAMHICIIIMMLFUAHIIEEAMGEFCAIUACMIHRUGIFGEUMM')
# Geracao 9, (93, 'HELGRMMICCILHUGLIGLRHGCRFMAMLALIGEIGMAIARAGMLCMLMHICIIIMMLFULEAHLAHHGEUCAIUACMIERUAIIGEUMM')
# (98, 'FEGURMMICCILHUGLIGLRHAUFMLLMHUEMHICRMAIACAGMLFMARAICIRIMMLFUMEMHLAEHGEMCAIUACMIHRUUIIGEUMM')
# (100, 'FEGURMMICCILHUGLIGLRHGUFMLLMHUEMHICRMAIACAGMLFMARAICIRIMMLFULEMHLAEHGEMCAIUACMIHRUAIIGEUMM')
# Geracao 12, (91, 'UEARGMMICCILHUGLIGLLHGCIFMAELARMGEIGMAIIRAGMLCMLMHICIIIMMLFULEAHLAHHGEUCAIUACMIERUFIIGEUMM')
# (92, 'UIARGMMICCILHUGLIGLMHGUFMLLCHAEMGEICMAILRAMMLLMARAICEIIRMLGRLEMHLAAHGGMCAIUACMIHLUAIIGEUMM')
# (92, 'HEGGRMMICCILHUGLIGLRHGCRFMAMAALIHICRMAIUFAGMLFMARMMCIUIMMLCULEMHLMEHMELCAIUACMILRUGIFGEUMM')
# Geracao 13, (84, 'UIARGMMICCILHUGLIGLMHIUFMLLCHAEMGEICMAILRAMMLLMARAICIIIMMLFULEACLAHHGEUCAIUACMIHLUAIIGEUMM')
# (84, 'FEARCCMICCILHUGLIGLIHGCFMLLALAHIGEHIMAIARAGMLFMARAUCIIIMMLFULEMHLMEHMELCAIUACMILRUGIFGEUMM')
# (88, 'FELERMMICCILHHGMIGLHHGUFMLLMHUMMGAIAMMMURLGMLFRGRIIEIRICMLFULEMHLMEHMIFCAIUACMIMRUAIIGEUML')
# Geracao 15, (78, 'HELGRMMICCILHFULIGLRHMCRFMAMLALIGEILMALARALMLUMLMHICIFIIMLCULEAHLMAHGGMCAIUACMIERCHIIGHUML')
# (80, 'UIARGCMICCIEHUGLIGLMHIUFMLLCHAEMGEACMAILRAMMGLMARAICIIIMMLFULEMHLMEHMELCAIUACMILRUGIFGEUMM')
# (80, 'FELFRMMICCILHHGLIGLHHGUFMLLMAURMGEIGMAIIGAGULCRLMHICILIMMLFULIMHLACHGEMCAIUACMIHRUFIIGEUMM')
# Geracao 17, (75, 'UIARGMMICCILHUGLIGLMHIUFMLLCHAEMGEICMAILRAGMLFMARAUCIIIMMLFULEMHLMFMMELCAIUACMIHLUAIILEUMM')
# (78, 'HELGRMMICCILHFULIGLRHMCRFMAMLALIGEILMALARALMLUMLMHICIFIIMLCULEAHLMAHGGMCAIUACMIERCHIIGHUML')
# (79, 'FELFRMMICCILHHGLIGLHHGUFMLLMAUMMGEIGMAIIGAGULCRLMHICILIMMLFULIMHLHCHGEMCAIUACMIHRUFIAGEUMM')
# Geracao 18, (74, 'UIARGMMICCILHMGLIGLMHICRFMAMLALIGEILMALARALMLUMLMHICIFIIMLCULEAHLMAHGGMCAIEACMIERCHIIGHUML')
# Geracao 28, (51, 'HELGRMMICCILHLGLIILFLCMRFMAMLALIGUILMLILRAMMLLMLMHICIICIHAUULIMLLMLMMILCAIUACMIHLUAFIGEUGM')
# (53, 'HELGRMMICCILHLGLIGLFLMMRFMAILALIGEILMAILRAMMLLMLMHICIICIMACULEMHLMFHMIUCAIUALMIHLUAIIGHLML')
# (53, 'LIAGRMMICCILHMGLIGLMUICRFMAMLALIGEILMGLARALMLUMLMHICIFIMMLRULHMHLMEHMIUCAILGCMIGLULIFGELMM')
# Geracao 31, (47, 'IELGRMMICCILHMGLHGLMUIFRFMAMLMLIGEILMGLAUALMLUMLMHILIICIMLCULIALLMFMMILCEIUACMIHLUAFIGHRML')
# (50, 'IIARLMMICRILHHMLIGLGHMCLLLMMAAHEGCILMFILRALMLUMLMHICELIMMLFALEMHLMEGMELCAIUACMIIRILIIFHRML')
# (50, 'HELARMMICRILHMGLIGLMUICRFMAMLALIGEILMGLARALMLUMLMHICIFHIMLCULEMULACMMILCAIFACMIHRCLIIGEUMM')
# Geracao 32, (45, 'HELGRMMICCILHLGLIGLFLCMRFMAILALIGEILMGLARALMLUMLMHICIFIMMLCULHMLLMFMMILLAIUACMIIRILIFFHRML')
# (47, 'IELGRMMICCILHMGLHGLMUIFRFMAMLMLIGEILMGLAUALMLUMLMHILIICIMLCULIALLMFMMILCEIUACMIHLUAFIGHRML')
# (47, 'IIAFGAMIIRILHHMLIGLMHMCLLLLMAAHEGCILMFILRALMLGMLMHICELIMMLCULEMHLIEHMELCAIUAGMIILULIFGELML')
# Geracao 40, (44, 'IIARLMMICRIFHGMLIGLMHMCLLLLMAALIGEILMCLARALMLUMLMHICIHRMMLRULMHLLMEHMIUCRILGCMIIRILFIFALMM')
# (44, 'IELGRMMICCILHUGLIGLMHIUFLLLMAAHEGLILMALARALFLUMLMHICILIMMLCULMILLMLMMILCAHLGCMIGLUAIIIHLMM')
# (45, 'HELGRMMICCILHLGLIGLFLCMRFMAILALIGEILMGLARALMLUMLMHICIFIMMLCULHMLLMFMMILLAIUACMIIRILIFFHRML')
# Geracao 44, (34, 'IIAGGMMFCRILHCMLIGLMHMCLLLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (43, 'IIARLMMICRIFHGMLIGLMHMCLLLLMAALIGEILMALLRFMMLLMLMHICIICMMLFULEGLLMRGMELCAIUACMIIRGLIIFHLMM')
# (44, 'IIARLMMICRIFHGMLIGLMHMCLLLLMAALIGEILMCLARALMLUMLMHICIHRMMLRULMHLLMEHMIUCRILGCMIIRILFIFALMM')
# Geracao 53, (33, 'IELFGAMIIRILHUMLIILGHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGMGLCAIUACMIIRILIIFHLMA')
# (34, 'IIAGGMMFCRILHCMLIGLMHMCLLLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (37, 'IELFGAMIIRILHUMLIGLMHMCLCLLMAAHEGCILMFILRALMLGMLMHILIICMMLFULEGHLMEGMELCAIUACMIIRILIIFHLMM')
# Geracao 61, (32, 'IELFGAMIIRILHUMLIGLMHMCLCLLMAAHEGCILMFILRALMLGMLMAICIIHMMLFULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (32, 'IELFGAMIIRILHUMLIILMHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMUCULHMLLMEGGGLCAIMACMIIRILIIFHLMM')
# (33, 'IELFGAMIIRILHUMLIILGHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGMGLCAIUACMIIRILIIFHLMA')
# Geracao 64, (30, 'IMAGGAMIIRILHUMLIGLMHMCLCLLMLALEGCILMILARILMLUMLMHICIFHMMLFULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (32, 'IELFGAMIIRILHUMLIGLMHMCLCLLMAAHEGCILMFILRALMLGMLMAICIIHMMLFULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (32, 'IELFGAMIIRILHUMLIILMHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMUCULHMLLMEGGGLCAIMACMIIRILIIFHLMM')
# Geracao 74, (29, 'IELFGAMIIRILHUMLIILMHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGGGLCAIMACMIIRILIIFHLMM')
# (30, 'IMAGGAMIIRILHUMLIGLMHMCLCLLMLALEGCILMILARILMLUMLMHICIFHMMLFULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# (30, 'MELFGAMIIRILHUMLIILGHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLFULHMLLMEGMELCAIUACMIIRILIIFHLMM')
# Geracao 81, (27, 'IELRGAMIGRILMUMLIILMHMCLCLHMLAGEGCILMFILRALMLHMLMHICIFHMMLCULHMLLMLGMELCAIUALMIIRILIIFHCMM')
# (29, 'IELFGAMIIRILHUMLIILMHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLCULHMLLMEGGGLCAIMACMIIRILIIFHLMM')
# (29, 'IELFGAMIIRILHUMLIGLMHMCLCLLMLALEGCILMGLARALMLUMLMHICIFHMMLHULHMLLMEGMGLCAIUACMIIRLLIIFHLMM')
# Geracao 86, (25, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMEGMGLCAIUACMIIRGLIIFHLMM')
# (26, 'IELRGAMIGRILMUMLIILMHMCLCLHMLAGEGCILMFILRALMLHMLMHICIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (27, 'IELRGAMIGRILMUMLIILMHMCLCLHMLAGEGCILMFILRALMLHMLMHICIFHMMLCULHMLLMLGMELCAIUALMIIRILIIFHCMM')
# Geracao 91, (24, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMLGMELCAIUAGMIIRRLIIFHCMM')
# (25, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMEGMGLCAIUACMIIRGLIIFHLMM')
# (26, 'IELRGAMIGRILMUMLIILMHMCLCLHMLAGEGCILMFILRALMLHMLMHICIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 97, (23, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARARMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (24, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMLGMELCAIUAGMIIRRLIIFHCMM')
# (24, 'UMLFLAMIIRIEHUMLIGLMHMCLCLLMHALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# Geracao 102, (21, 'IELFGAMIGRILMUMLIILMHMCLCLLMMALEGCILMGLARALMLUMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (23, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARARMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (24, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMLGMELCAIUAGMIIRRLIIFHCMM')
# Geracao 109, (20, 'CELFGARIIRILHUMLIGLMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (21, 'IELFGAMIGRILMUMLIILMHMCLCLLMMALEGCILMGLARALMLUMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (23, 'IELFGARIIRILHUMLIILMHMMLCLLMMALEGCILMGLARARMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# Geracao 113, (18, 'IELFGAHIGRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHIMLCULHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (20, 'CELFGARIIRILHUMLIGLMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (21, 'IELFGAMIGRILMUMLIILMHMCLCLLMMALEGCILMGLARALMLUMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 115, (17, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGILRALMLHMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (18, 'IELFGAHIGRILHUMLIILMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHIMLCULHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (20, 'CELFGARIIRILHUMLIGLMHMMLCLLMMALEGCILMGLARALMLIMLMHICIFHMMLCULHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# Geracao 130, (16, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGILRALMLHMLMHILIFHMMLCILHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (17, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGILRALMLHMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (17, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGELRALMLHMLMHILIFAMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 151, (15, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (16, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGILRALMLHMLMHILIFHMMLCILHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# (16, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGILRALMLHMLMHILIFHMMLCILHMLLMGLMELCAIUALMIIRGLIIFHCMM')
# Geracao 183, (14, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCGIUALMIIRALIIFHCMM')
# (15, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (15, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 210, (11, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (14, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCGIUALMIIRALIIFHCMM')
# (14, 'IMLFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 212, (10, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (11, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# (14, 'IELFGAHIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCGIUALMIIRALIIFHCMM')
# Geracao 217, (9, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (10, 'IELFGAMIGRILHUMLIILMHMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (11, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMLGMELCAIUALMIIRGLIIFHCMM')
# Geracao 297, (8, 'IMLFGAHIGRILHUMLIILEMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (9, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (9, 'IELFGAHIGRILHUMLIILMMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# Geracao 667, (7, 'CMLFGAHIGRILHUMLIILEMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (8, 'IMLFGAHIGRILHUMLIILEMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (8, 'IMLFGAHIGRILHUMLIILEMMMLCLLMCAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# Geracao 13445, (6, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (7, 'CMLFGAHIGRILHUMLIILEMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (7, 'CMLFGAHIGRILHUMLIILEMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# Geracao 31480, (5, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# (6, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# (6, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLMGLMELCGIUALMIIRALIIFHCMM')
# Geracao 32374, (4, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAMEGCILMGLARALMLIULMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# (5, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# (5, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAUEGCILMGLARALMLIMLMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# Geracao 43899, (3, 'CMLFEAHMGRILHUMLIILGMMMLCLLIIAMEGCILMGLARALMLIULMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# (4, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAMEGCILMGLARALMLIULMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
# (4, 'CMLFEAHIGRILHUMLIILGMMMLCLLMIAMEGCILMGLARALMLIULMHILIFHMMLCILHMLLIGLMELCGIUALMIIRALIMFHCMM')
